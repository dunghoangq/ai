# %% [markdown]
# # RAG - Langchain Tryout
#
# In first-principles thinking, there are four mathematical steps.
#
# 1. Raw Text
# 2. Chunking
# 3. Embedding
# 4. Vector Search (Nearest-neighbour Search)
# 5. LLM

# %% [markdown]
# ## Init

# %%
import os, sys

from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_community.document_loaders import TextLoader, PyPDFLoader, WebBaseLoader
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_25968\4289441619.py:5: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader, PyPDFLoader, WebBaseLoader
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# ## Pipeline
#
# 1. Load document.
# 2. Chunking
# 3. Embedding
# 4. Vector DB
# 5. Retrieve
# 6. Generation

# %% [markdown]
# ### Load Documents

# %%
src_doc = r"G:\My Drive\0-Studies\ml\books\mml\mml-book.pdf"

# %%
documents = load_documents()

vectorstore = Chroma.from_documents(
    documents,
    OpenAIEmbeddings()
)

retriever = vectorstore.as_retriever()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 documents = OpenAIEmbeddings.load_documents()
#       2
#       3 vectorstore = Chroma.from_documents(
#       4     documents,
#
# File d:\code\having_fun\rag\.venv\Lib\site-packages\pydantic\_internal\_model_construction.py:290, in ModelMetaclass.__getattr__(self, item)
#     288 if private_attributes and item in private_attributes:
#     289     return private_attributes[item]
# --> 290 raise AttributeError(item)
#
# AttributeError: load_documents
